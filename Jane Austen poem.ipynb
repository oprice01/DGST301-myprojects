# %%
# !pip install textblob
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
with open('JaneAusten.txt', 'r') as file:
    text = file.read()
    import random
    from textblob import TextBlob
blob = TextBlob(text)
adjectives = []
nouns = []
verbs = []
pronouns = []
adverbs = []
prepositions = []
modals = []
for word,pos in blob.tags:
    print(word,pos)
    if (pos == 'JJ'):
        adjectives.append(word)
    if (pos == 'NN'):
        nouns.append(word)
    if (pos == 'VBD'):
        verbs.append(word)
    if (pos == 'PRP'):
        pronouns.append(word)
    if (pos == 'RB'):
        adverbs.append(word)
    if (pos == 'IN'):
        prepositions.append(word)
    if (pos == 'MD'):
        modals.append(word)
# Out:
# ﻿The NN
# Project NNP
# Gutenberg NNP
# EBook NNP
# of IN
# Sense NNP
# and CC
# Sensibility NNP
# by IN
# Jane NNP
# Austen NNP
# This DT
# eBook NN
# is VBZ
# for IN
# the DT
# use NN
# of IN
# anyone NN
# anywhere RB
# at IN
# no DT
# cost NN
# and CC
# with IN
# almost RB
# no DT
# restrictions NNS
# whatsoever RB
# You PRP
# may MD
# copy VB
# it PRP
# give VB
# it PRP
# away RB
# or CC
# re-use VB
# it PRP
# under IN
# the DT
# terms NNS
# of IN
# the DT
# Project NNP
# Gutenberg NNP
# License NNP
# included VBD
# with IN
# this DT
# eBook NN
# or CC
# online NN
# at IN
# www.gutenberg.org JJ
# Title NN
# Sense NN
# and CC
# Sensibility NNP
# Author NNP
# Jane NNP
# Austen NNP
# Commentator NNP
# Austin NNP
# Dobson NNP
# Illustrator NNP
# Hugh NNP
# Thomson NNP
# Release NNP
# Date NNP
# June NNP
# 15 CD
# 2007 CD
# [ NNP
# EBook NNP
# 21839 CD
# ] NN
# [ NN
# Last JJ
# updated JJ
# February NNP
# 11 CD
# 2015 CD
# ] JJ
# Language NNP
# English JJ
# *** NNP
# START NNP
# ...

# %%
for i in range(8):
    p1 = random.choice(pronouns)
    a1 = random.choice(adjectives)
    n1 = random.choice(nouns)
    n2 = random.choice(nouns)
    v1 = random.choice(verbs)
    ad1 = random.choice(adverbs)
    pr1 = random.choice(prepositions)
    print(p1 + " " + ad1 + " " + v1 + " " +  n1  + " " + pr1 + " " + a1  + " " + n2)
# Out:
# he too did education from happy loss
# I not looked affection in literary time
# they down had regard by sure news
# I ago thought duty for previous report
# him well quitted music for same sister
# we so were sister of _Your_ admiration
# you well left man in late pride
# He greatly thought fortune that fresh morning

# %%
for i in range(6):
    p1 = random.choice(pronouns)
    a1 = random.choice(adjectives)
    n1 = random.choice(nouns)
    n2 = random.choice(nouns)
    v1 = random.choice(verbs)
    v2 = random.choice(verbs)
    ad1 = random.choice(adverbs)
    pr1 = random.choice(prepositions)
    m1 = random.choice(modals)
    print(p1 + " " + ad1 + " " + v1 + " " +  n1  + " " + pr1 + " " + a1  + " " + n2)
for i in range (1):
    p1 = random.choice(pronouns)
    a1 = random.choice(adjectives)
    n1 = random.choice(nouns)
    n2 = random.choice(nouns)
    v1 = random.choice(verbs)
    v2 = random.choice(verbs)
    ad1 = random.choice(adverbs)
    pr1 = random.choice(prepositions)
    m1 = random.choice(modals)
    print('\n' + a1 + " " + n1 + " " + ad1 + " " + v2)
# Out:
# she hardly replied upon by able promise
# I back fled body In frank nothing
# they only gave life of melancholy mistake
# they far said belief With unjust occasion
# it now attempted account in much left
# I seriously was consonance out much generosity
#
# great _Pride only contradicted
